# %% [markdown]
# <a href="https://colab.research.google.com/github/endtailer007/my_first_repo/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hardware is the physical components of a system and software is non physical which uses programs to instruct hardware how to perform tasks, to put it simply. Software is the brain of the system and hardware is the body.
